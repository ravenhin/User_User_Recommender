# %% [markdown]
# # Simple Clothing Recommender
#
# In order to create a clothing recommender, I found data from the website Rent the Runway from this [website](https://cseweb.ucsd.edu/~jmcauley/datasets.html). In this notebook, I will walk through the code as to how I created a simple recommender. When I say simple, I mean that my recommender for this notebook only has three variables, and only one in which it is making recommendations off of. The one variable that is needed for making any kind of recommender such as this is rating data. Due to the fact that this data set has a rating variable, I am able to make a recommender for users based on the rating they gave certain article of clothing. In this notebook, I am also only using a very small portion of the data that is available to practice creating the recommender on. The reason is because my computer was not able to handle all of the data, which was 192,544 samples. When creating the simple recommender in this notebook, I only used 5,000 samples. In another notebook, in which I was cloud computing, I was able to create the recommender that could take in all of the data points. The recommender made from this notebook of course was not able to recommend as well because it was not exposed to as more data. While more data can sometimes make a recommender, this may not always be the case because you may just have products that are all equally liked by users therefore does not hold as much value. So in the end it really just depends on the amount of products and users that a store or company has that could determine if adding a recommender for their users in worth it or not.
#
#
# ### Importing Data
# Below I imported pandas in order to import the data into a dataframe in the notebook. The file below is in a JSON format, but when downloading it straight from the website in came in the format of a gzip, so I used a file converting website that allowed me to unzip the data, and save it in a JSON format.

# %%
import pandas as pd

# %%
rent = pd.read_json('renttherunway_final_data.json', lines = True)

# %%
rent.index
# Out:
# RangeIndex(start=0, stop=192544, step=1)

# %% [markdown]
# ### Inspecting the Data
#
# Below I printed the data frame, in order to get an understanding of the columns and amount of samples I had. After looking at the columns, I knew for the recommender I was building I was only needed to use the following three variables:
#  - user_id
#  - rating
#  - category
#
# I knew that I needed these because I need the item name I was recommending, which was category, a variable that idenified the user, and a variable that the recommender was going to make recommendations off of.
#
# I inspected each of these variables to see how many null values there were for each of these varaibles, how many categories their were, and how many rating categories there were.

# %%
rent
# Out:
#         fit  user_id bust size  item_id  weight  rating     rented for  \
# 0       fit   420272       34d  2260466  137lbs    10.0       vacation
# 1       fit   273551       34b   153475  132lbs    10.0          other
# 2       fit   360448       NaN  1063761     NaN    10.0          party
# 3       fit   909926       34c   126335  135lbs     8.0  formal affair
# 4       fit   151944       34b   616682  145lbs    10.0        wedding
# ...     ...      ...       ...      ...     ...     ...            ...
# 192539  fit    66386      34dd  2252812  140lbs    10.0           work
# 192540  fit   118398       32c   682043  100lbs    10.0           work
# 192541  fit    47002       36a   683251  135lbs     6.0       everyday
# 192542  fit   961120       36c   126335  165lbs    10.0        wedding
# 192543  fit   123612       36b   127865  155lbs    10.0        wedding
#
#                                               review_text          body type  \
# 0       An adorable romper! Belt and zipper were a lit...          hourglass
# 1       I rented this dress for a photo shoot. The the...  straight & narrow
# 2       This hugged in all the right places! It was a ...                NaN
# 3       I rented this for my company's black tie award...               pear
# 4       I have always been petite in my upper body and...           athletic
# ...                                                   ...                ...
# 192539                                  Fit like a glove!          hourglass
# 192540  The pattern contrast on this dress is really s...             petite
# 192541  Like the other DVF wraps, the fit on this is f...  straight & narrow
# 192542  This dress was PERFECTION.  it looked incredib...               pear
# 192543  This dress was wonderful! I had originally pla...           athletic
#
#                                            review_summary  category height  \
# 0                                    So many compliments!    romper  5' 8"
# 1                                 I felt so glamourous!!!      gown  5' 6"
# 2       It was a great time to celebrate the (almost) ...    sheath  5' 4"
# 3        Dress arrived on time and in perfect condition.      dress  5' 5"
# 4                         Was in love with this dress !!!      gown  5' 9"
# ...                                                   ...       ...    ...
# 192539       LOVE IT!!! First Item Im thinking of buying!  jumpsuit  5' 9"
# 192540                                           LOVE it!     dress  5' 1"
# 192541                    Loud patterning, flattering fit     dress  5' 8"
# 192542  loved this dress it was comfortable and photog...     dress  5' 6"
# 192543  I wore this to a beautiful black tie optional ...      gown  5' 6"
#
#         size    age         review_date
# 0         14   28.0      April 20, 2016
# 1         12   36.0       June 18, 2013
# 2          4  116.0   December 14, 2015
# 3          8   34.0   February 12, 2014
# 4         12   27.0  September 26, 2016
# ...      ...    ...                 ...
# 192539     8   42.0        May 18, 2016
# 192540     4   29.0  September 30, 2016
# 192541     8   31.0       March 4, 2016
# 192542    16   31.0   November 25, 2015
# 192543    16   30.0     August 29, 2017
#
# [192544 rows x 15 columns]

# %%
rent.isnull().sum()
# Out:
# fit                   0
# user_id               0
# bust size         18411
# item_id               0
# weight            29982
# rating               82
# rented for           10
# review_text           0
# body type         14637
# review_summary        0
# category              0
# height              677
# size                  0
# age                 960
# review_date           0
# dtype: int64

# %%
#After noticing that of the variables I was observing, rating was the only one that had missing values, I wrote the
# following code to drop the samples that had missing data. Since I was only losing .04% of the total sample, I knew
#this was the best choice rather than inputing the values because it was such a minmial amount of data that it would
#not affect the recommnder at all.
rent.dropna(subset = ['rating'], inplace = True)

# %%
rent['rating'].isnull().sum()
# Out:
# 0

# %%
#Here I dropped enough data so that I could practice writing that code I needed to make the recommender since this data
#set was too large for me to create within this notbook.
rent.drop(rent.index[5001:192543],0, inplace = True)

# %%
#Then I inspected the value counts of the ratings to understand how my recommender might be biased. Looking at the 
#value counts below shows me that my recommender will mostly have similar recommendations to give since most clothes
#are rated as an 8 or 10.
rent['rating'].value_counts()
# Out:
# 10.0    3197
# 8.0     1402
# 6.0      288
# 4.0       90
# 2.0       24
# Name: rating, dtype: int64

# %%
#In this cell I wanted to see what amount of clothes existed within each category to understand what clothing 
#categories would have more than others in order to better understand once I see the final product of the recommender. 
rent['category'].value_counts()
# Out:
# dress         2414
# gown          1155
# sheath         491
# shift          142
# jumpsuit       133
# top            124
# romper          86
# maxi            80
# jacket          54
# skirt           50
# mini            48
# sweater         36
# coat            29
# blazer          25
# blouse          20
# shirtdress      17
# down            17
# pants            9
# culottes         9
# shirt            6
# vest             6
# frock            6
# bomber           5
# tunic            4
# pant             3
# cape             3
# cardigan         3
# tank             3
# print            2
# leggings         2
# suit             2
# poncho           2
# knit             2
# sweatshirt       2
# trouser          2
# legging          2
# culotte          1
# midi             1
# ballgown         1
# peacoat          1
# pullover         1
# trench           1
# duster           1
# Name: category, dtype: int64

# %%
#I wanted to make sure I knew that I had dropped all the cells before trying to create the recommender, and in this 
#dataframe below, you can see that there is only 5001 samples.
rent
# Out:
#         fit  user_id bust size  item_id  weight  rating     rented for  \
# 0       fit   420272       34d  2260466  137lbs    10.0       vacation
# 1       fit   273551       34b   153475  132lbs    10.0          other
# 2       fit   360448       NaN  1063761     NaN    10.0          party
# 3       fit   909926       34c   126335  135lbs     8.0  formal affair
# 4       fit   151944       34b   616682  145lbs    10.0        wedding
# ...     ...      ...       ...      ...     ...     ...            ...
# 4996    fit   655656       36d   259136  140lbs    10.0          other
# 4997    fit   188946       34b   125424  110lbs    10.0          party
# 4998  large   581325       38d  1614539  180lbs     8.0  formal affair
# 4999    fit   616038       34d  2347208  120lbs    10.0           work
# 5000    fit   151583       36c  1869763  135lbs    10.0        wedding
#
#                                             review_text          body type  \
# 0     An adorable romper! Belt and zipper were a lit...          hourglass
# 1     I rented this dress for a photo shoot. The the...  straight & narrow
# 2     This hugged in all the right places! It was a ...                NaN
# 3     I rented this for my company's black tie award...               pear
# 4     I have always been petite in my upper body and...           athletic
# ...                                                 ...                ...
# 4996  The dress zipped up smoothly. It fit perfectly...           athletic
# 4997  This dress fits perfectly! It's simple and def...             petite
# 4998  This dress was extremely comfortable, very swa...          full bust
# 4999  Hung well and didn't look too boxy...even over...          full bust
# 5000  I normally wear a 6 but ended up wearing the 8...          hourglass
#
#                                          review_summary category  height  \
# 0                                  So many compliments!   romper   5' 8"
# 1                               I felt so glamourous!!!     gown   5' 6"
# 2     It was a great time to celebrate the (almost) ...   sheath   5' 4"
# 3      Dress arrived on time and in perfect condition.     dress   5' 5"
# 4                       Was in love with this dress !!!     gown   5' 9"
# ...                                                 ...      ...     ...
# 4996  I wore this dress to a high school graduation ...   sheath   5' 5"
# 4997  This was the perfect dress for our winter enga...    dress  4' 11"
# 4998  The people I shared the event with and the dress!     gown   5' 6"
# 4999                                Perfect for work.       down   5' 4"
# 5000                              Sexy and cute dress!     shift   5' 5"
#
#       size    age         review_date
# 0       14   28.0      April 20, 2016
# 1       12   36.0       June 18, 2013
# 2        4  116.0   December 14, 2015
# 3        8   34.0   February 12, 2014
# 4       12   27.0  September 26, 2016
# ...    ...    ...                 ...
# 4996    12   41.0        June 5, 2016
# 4997     1   29.0       March 4, 2016
# 4998    32   26.0       March 1, 2016
# 4999     8   36.0       March 4, 2016
# 5000    16   25.0      August 1, 2016
#
# [5001 rows x 15 columns]

# %% [markdown]
# # Creating the Recommender
#
# In order to create a recommender, you need to have a dataframe of only the variables your recommender needs, so that you can create a pivot table. Once you have the pivot table you will need to to create a sparse matrix, and make sure to fill all the spaces where there are NAs (this happens because not every single user rates every single category of clothing) with zeros. After creating the sparse matrix, we have to find the cosine of each category in relation to each other. The closer the cosine is to 1 the more similaer those items are, which means that the user will like the category because it is similar to another category they like. If the cosine is close to zero, it means there is not really anything we can infer about whether or not a user will like it or not. If the cosine is close to -1, this gives us insight into the fact that a user would not like this at all, so we would never recommend it to them.

# %%
#In this cell, I have created the dataframe need to make the pivot table.
pt_df = rent[['user_id', 'rating', 'category']]

# %%
#Here I doubled checked that there were no null values one more time just to make sure.
pt_df.isnull().sum()
# Out:
# user_id     0
# rating      0
# category    0
# dtype: int64

# %%
#This cell is for creating the pivot table
piovt = pt_df.pivot_table(index = 'category', columns = 'user_id', values = 'rating')

# %%
#This cell contains imported need to create the recommender.
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances

# %%
#Here is where the sparse martix is created.
pivot_sparse = sparse.csr_matrix(piovt.fillna(0))

# %%
#This cell is where the cosine values of the categories are found.
recommender = pairwise_distances(pivot_sparse, metric = 'cosine')

# %%
#Checking to make sure the code is giving me the right output.
recommender
# Out:
# array([[0.        , 1.        , 1.        , ..., 1.        , 1.        ,
#         1.        ],
#        [1.        , 0.        , 0.95858166, ..., 1.        , 1.        ,
#         1.        ],
#        [1.        , 0.95858166, 0.        , ..., 1.        , 1.        ,
#         1.        ],
#        ...,
#        [1.        , 1.        , 1.        , ..., 0.        , 1.        ,
#         1.        ],
#        [1.        , 1.        , 1.        , ..., 1.        , 0.        ,
#         1.        ],
#        [1.        , 1.        , 1.        , ..., 1.        , 1.        ,
#         0.        ]])

# %%
#Here I created the dataframe of the recommender, in order to see what the recommendations are.
recommender_df = pd.DataFrame(recommender, columns = piovt.index, index = piovt.index)

# %%
#This is to see what the dataframe looks like.
recommender_df
# Out:
# category    ballgown    blazer    blouse    bomber      cape  cardigan  \
# category
# ballgown         0.0  1.000000  1.000000  1.000000  1.000000       1.0
# blazer           1.0  0.000000  0.958582  1.000000  1.000000       1.0
# blouse           1.0  0.958582  0.000000  1.000000  1.000000       1.0
# bomber           1.0  1.000000  1.000000  0.000000  1.000000       1.0
# cape             1.0  1.000000  1.000000  1.000000  0.000000       1.0
# cardigan         1.0  1.000000  1.000000  1.000000  1.000000       0.0
# coat             1.0  1.000000  1.000000  1.000000  1.000000       1.0
# culotte          1.0  1.000000  1.000000  1.000000  1.000000       1.0
# culottes         1.0  1.000000  1.000000  1.000000  1.000000       1.0
# down             1.0  1.000000  1.000000  1.000000  1.000000       1.0
# dress            1.0  0.988407  0.975980  0.989407  1.000000       1.0
# duster           1.0  1.000000  1.000000  1.000000  1.000000       1.0
# frock            1.0  1.000000  1.000000  1.000000  1.000000       1.0
# gown             1.0  0.989152  0.996354  1.000000  1.000000       1.0
# jacket           1.0  1.000000  1.000000  0.931222  0.942137       1.0
# jumpsuit         1.0  0.979485  0.981613  1.000000  1.000000       1.0
# knit             1.0  1.000000  1.000000  1.000000  1.000000       1.0
# legging          1.0  1.000000  1.000000  1.000000  1.000000       1.0
# leggings         1.0  1.000000  1.000000  1.000000  1.000000       1.0
# maxi             1.0  1.000000  1.000000  1.000000  0.936923       1.0
# midi             1.0  1.000000  1.000000  1.000000  1.000000       1.0
# mini             1.0  1.000000  1.000000  1.000000  1.000000       1.0
# pant             1.0  1.000000  1.000000  1.000000  1.000000       1.0
# pants            1.0  1.000000  1.000000  1.000000  1.000000       1.0
# peacoat          1.0  1.000000  1.000000  1.000000  1.000000       1.0
# poncho           1.0  1.000000  1.000000  1.000000  1.000000       1.0
# print            1.0  1.000000  1.000000  1.000000  1.000000       1.0
# pullover         1.0  1.000000  1.000000  1.000000  1.000000       1.0
# romper           1.0  0.974502  1.000000  1.000000  1.000000       1.0
# sheath           1.0  0.991527  0.992406  0.977128  1.000000       1.0
# shift            1.0  0.988031  1.000000  1.000000  1.000000       1.0
# shirt            1.0  1.000000  1.000000  1.000000  1.000000       1.0
# shirtdress       1.0  1.000000  1.000000  1.000000  1.000000       1.0
# skirt            1.0  1.000000  1.000000  1.000000  1.000000       1.0
# suit             1.0  1.000000  1.000000  1.000000  1.000000       1.0
# sweater          1.0  1.000000  1.000000  1.000000  1.000000       1.0
# sweatshirt       1.0  1.000000  1.000000  1.000000  1.000000       1.0
# tank             1.0  1.000000  1.000000  1.000000  1.000000       1.0
# top              1.0  0.983212  0.976488  1.000000  1.000000       1.0
# trench           1.0  1.000000  1.000000  1.000000  1.000000       1.0
# trouser          1.0  1.000000  1.000000  1.000000  1.000000       1.0
# tunic            1.0  1.000000  1.000000  1.000000  1.000000       1.0
# vest             1.0  1.000000  1.000000  1.000000  1.000000       1.0
#
# category        coat  culotte  culottes      down  ...     skirt  suit  \
# category                                           ...
# ballgown    1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# blazer      1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# blouse      1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# bomber      1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# cape        1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# cardigan    1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# coat        0.000000      1.0  1.000000  0.947473  ...  1.000000   1.0
# culotte     1.000000      0.0  1.000000  1.000000  ...  1.000000   1.0
# culottes    1.000000      1.0  0.000000  1.000000  ...  1.000000   1.0
# down        0.947473      1.0  1.000000  0.000000  ...  1.000000   1.0
# dress       0.985570      1.0  0.991933  0.994163  ...  0.984781   1.0
# duster      1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# frock       1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# gown        0.993524      1.0  1.000000  1.000000  ...  1.000000   1.0
# jacket      0.969581      1.0  1.000000  1.000000  ...  0.981615   1.0
# jumpsuit    0.980405      1.0  1.000000  1.000000  ...  0.985197   1.0
# knit        1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# legging     1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# leggings    1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# maxi        1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# midi        1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# mini        1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# pant        1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# pants       0.925716      1.0  1.000000  1.000000  ...  1.000000   1.0
# peacoat     1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# poncho      1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# print       1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# pullover    1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# romper      0.956163      1.0  1.000000  1.000000  ...  0.985281   1.0
# sheath      1.000000      1.0  1.000000  0.989917  ...  1.000000   1.0
# shift       0.980946      1.0  1.000000  1.000000  ...  1.000000   1.0
# shirt       1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# shirtdress  1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# skirt       1.000000      1.0  1.000000  1.000000  ...  0.000000   1.0
# suit        1.000000      1.0  1.000000  1.000000  ...  1.000000   0.0
# sweater     1.000000      1.0  1.000000  1.000000  ...  0.968927   1.0
# sweatshirt  1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# tank        1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# top         0.979956      1.0  0.965485  0.965036  ...  0.978194   1.0
# trench      1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# trouser     1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
# tunic       1.000000      1.0  1.000000  1.000000  ...  0.914350   1.0
# vest        1.000000      1.0  1.000000  1.000000  ...  1.000000   1.0
#
# category     sweater  sweatshirt  tank       top  trench   trouser     tunic  \
# category
# ballgown    1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# blazer      1.000000         1.0   1.0  0.983212     1.0  1.000000  1.000000
# blouse      1.000000         1.0   1.0  0.976488     1.0  1.000000  1.000000
# bomber      1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# cape        1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# cardigan    1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# coat        1.000000         1.0   1.0  0.979956     1.0  1.000000  1.000000
# culotte     1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# culottes    1.000000         1.0   1.0  0.965485     1.0  1.000000  1.000000
# down        1.000000         1.0   1.0  0.965036     1.0  1.000000  1.000000
# dress       0.980072         1.0   1.0  0.967301     1.0  0.982183  0.987401
# duster      1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# frock       1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# gown        1.000000         1.0   1.0  0.987684     1.0  0.975371  1.000000
# jacket      1.000000         1.0   1.0  0.959504     1.0  0.810273  1.000000
# jumpsuit    0.980883         1.0   1.0  0.990684     1.0  1.000000  0.947306
# knit        1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# legging     1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# leggings    1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# maxi        1.000000         1.0   1.0  0.988175     1.0  1.000000  1.000000
# midi        1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# mini        1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# pant        1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# pants       1.000000         1.0   1.0  0.964681     1.0  1.000000  1.000000
# peacoat     1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# poncho      1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# print       1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# pullover    0.839743         1.0   1.0  1.000000     1.0  1.000000  1.000000
# romper      0.957231         1.0   1.0  0.965263     1.0  1.000000  0.947606
# sheath      1.000000         1.0   1.0  0.982493     1.0  0.961527  1.000000
# shift       1.000000         1.0   1.0  0.990941     1.0  0.927536  1.000000
# shirt       1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# shirtdress  1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# skirt       0.968927         1.0   1.0  0.978194     1.0  1.000000  0.914350
# suit        1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
# sweater     0.000000         1.0   1.0  0.972622     1.0  1.000000  0.889391
# sweatshirt  1.000000         0.0   1.0  1.000000     1.0  1.000000  1.000000
# tank        1.000000         1.0   0.0  1.000000     1.0  1.000000  1.000000
# top         0.972622         1.0   1.0  0.000000     1.0  0.923770  1.000000
# trench      1.000000         1.0   1.0  1.000000     0.0  1.000000  1.000000
# trouser     1.000000         1.0   1.0  0.923770     1.0  0.000000  1.000000
# tunic       0.889391         1.0   1.0  1.000000     1.0  1.000000  0.000000
# vest        1.000000         1.0   1.0  1.000000     1.0  1.000000  1.000000
#
# category    vest
# category
# ballgown     1.0
# blazer       1.0
# blouse       1.0
# bomber       1.0
# cape         1.0
# cardigan     1.0
# coat         1.0
# culotte      1.0
# culottes     1.0
# down         1.0
# dress        1.0
# duster       1.0
# frock        1.0
# gown         1.0
# jacket       1.0
# jumpsuit     1.0
# knit         1.0
# legging      1.0
# leggings     1.0
# maxi         1.0
# midi         1.0
# mini         1.0
# pant         1.0
# pants        1.0
# peacoat      1.0
# poncho       1.0
# print        1.0
# pullover     1.0
# romper       1.0
# sheath       1.0
# shift        1.0
# shirt        1.0
# shirtdress   1.0
# skirt        1.0
# suit         1.0
# sweater      1.0
# sweatshirt   1.0
# tank         1.0
# top          1.0
# trench       1.0
# trouser      1.0
# tunic        1.0
# vest         0.0
#
# [43 rows x 43 columns]

# %%
#This is where I tested the recommender based on one category, it starts with the least related and goes to the most
#related but only shows the top 10.
recommender_df['romper'].sort_values()[1:11]
# Out:
# category
# tunic       0.947606
# coat        0.956163
# pants       0.957088
# sweater     0.957231
# top         0.965263
# blazer      0.974502
# dress       0.977808
# jacket      0.982427
# skirt       0.985281
# jumpsuit    0.990944
# Name: romper, dtype: float64

# %%
recommender_df['cardigan'].sort_values()[1:11]
# Out:
# category
# ballgown      1.0
# peacoat       1.0
# poncho        1.0
# print         1.0
# pullover      1.0
# romper        1.0
# sheath        1.0
# shift         1.0
# shirt         1.0
# shirtdress    1.0
# Name: cardigan, dtype: float64

# %%
#In order to see the top 10 recommender categories for each category, I have the following code posted.

for col in recommender_df.columns:
    print(col)
    print(recommender_df[col].sort_values(ascending = False)[1:11])
    print()
# Out:
# ballgown
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: ballgown, dtype: float64
#
# blazer
# category
# frock       1.0
# tunic       1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jacket      1.0
# duster      1.0
# pants       1.0
# Name: blazer, dtype: float64
#
# blouse
# category
# frock       1.0
# tunic       1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jacket      1.0
# duster      1.0
# pants       1.0
# Name: blouse, dtype: float64
#
# bomber
# category
# pant        1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# gown        1.0
# frock       1.0
# duster      1.0
# Name: bomber, dtype: float64
#
# cape
# category
# pant        1.0
# midi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# gown        1.0
# frock       1.0
# duster      1.0
# dress       1.0
# Name: cape, dtype: float64
#
# cardigan
# category
# duster      1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# dress       1.0
# Name: cardigan, dtype: float64
#
# coat
# category
# peacoat     1.0
# tunic       1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# frock       1.0
# duster      1.0
# culottes    1.0
# Name: coat, dtype: float64
#
# culotte
# category
# duster      1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# dress       1.0
# Name: culotte, dtype: float64
#
# culottes
# category
# tunic       1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# Name: culottes, dtype: float64
#
# down
# category
# pant        1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# Name: down, dtype: float64
#
# dress
# category
# pullover    1.0
# cape        1.0
# cardigan    1.0
# culotte     1.0
# duster      1.0
# frock       1.0
# knit        1.0
# legging     1.0
# leggings    1.0
# midi        1.0
# Name: dress, dtype: float64
#
# duster
# category
# dress       1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# down        1.0
# Name: duster, dtype: float64
#
# frock
# category
# dress       1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# duster      1.0
# down        1.0
# Name: frock, dtype: float64
#
# gown
# category
# frock       1.0
# tunic       1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# duster      1.0
# peacoat     1.0
# down        1.0
# Name: gown, dtype: float64
#
# jacket
# category
# peacoat     1.0
# pant        1.0
# tunic       1.0
# midi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# frock       1.0
# duster      1.0
# Name: jacket, dtype: float64
#
# jumpsuit
# category
# peacoat     1.0
# pant        1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jacket      1.0
# frock       1.0
# duster      1.0
# Name: jumpsuit, dtype: float64
#
# knit
# category
# dress       1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: knit, dtype: float64
#
# legging
# category
# dress       1.0
# maxi        1.0
# leggings    1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: legging, dtype: float64
#
# leggings
# category
# dress       1.0
# maxi        1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: leggings, dtype: float64
#
# maxi
# category
# duster      1.0
# midi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# gown        1.0
# frock       1.0
# down        1.0
# pant        1.0
# Name: maxi, dtype: float64
#
# midi
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: midi, dtype: float64
#
# mini
# category
# duster      1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# down        1.0
# Name: mini, dtype: float64
#
# pant
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: pant, dtype: float64
#
# pants
# category
# pant        1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# frock       1.0
# duster      1.0
# Name: pants, dtype: float64
#
# peacoat
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: peacoat, dtype: float64
#
# poncho
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: poncho, dtype: float64
#
# print
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: print, dtype: float64
#
# pullover
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: pullover, dtype: float64
#
# romper
# category
# duster      1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# frock       1.0
# down        1.0
# peacoat     1.0
# culottes    1.0
# Name: romper, dtype: float64
#
# sheath
# category
# knit        1.0
# pant        1.0
# tunic       1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# frock       1.0
# poncho      1.0
# duster      1.0
# Name: sheath, dtype: float64
#
# shift
# category
# frock       1.0
# tunic       1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# duster      1.0
# pants       1.0
# Name: shift, dtype: float64
#
# shirt
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: shirt, dtype: float64
#
# shirtdress
# category
# duster      1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# down        1.0
# Name: shirtdress, dtype: float64
#
# skirt
# category
# down        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# gown        1.0
# frock       1.0
# duster      1.0
# culottes    1.0
# pant        1.0
# Name: skirt, dtype: float64
#
# suit
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: suit, dtype: float64
#
# sweater
# category
# pant        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: sweater, dtype: float64
#
# sweatshirt
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: sweatshirt, dtype: float64
#
# tank
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: tank, dtype: float64
#
# top
# category
# print       1.0
# bomber      1.0
# cape        1.0
# cardigan    1.0
# culotte     1.0
# duster      1.0
# frock       1.0
# knit        1.0
# legging     1.0
# leggings    1.0
# Name: top, dtype: float64
#
# trench
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: trench, dtype: float64
#
# trouser
# category
# pant        1.0
# midi        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: trouser, dtype: float64
#
# tunic
# category
# pant        1.0
# maxi        1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: tunic, dtype: float64
#
# vest
# category
# dress       1.0
# leggings    1.0
# legging     1.0
# knit        1.0
# jumpsuit    1.0
# jacket      1.0
# gown        1.0
# frock       1.0
# duster      1.0
# down        1.0
# Name: vest, dtype: float64

# %% [markdown]
# # Clothing Recommender
#
# To see the recommender using all of the samples from the original data, except the samples that are missing the value for rating. [Click here](https://colab.research.google.com/drive/1467ZodIPj_ZBPfjPKWWnuTj3zR--LqB_). This is all the same code as above.
